# %% [markdown]
# <h1>  EDA - Forest Fire Data Set </h1>

# %% [markdown]
# <h4>Import packages.</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import seaborn as sns
import statistics as st
from scipy import stats
from IPython.display import display
pd.options.display.max_columns = 100 #(to unlimit the varibles)
pd.set_option('display.max_rows', None)
import statsmodels.api as sm
from sklearn import metrics

# %%
forestfire = pd.read_csv("../Data/Forest-Fire-prediction/forestfires.csv")

# %%
forestfire.head(5)
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
forestfire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
# X        517 non-null int64
# Y        517 non-null int64
# month    517 non-null object
# day      517 non-null object
# FFMC     517 non-null float64
# DMC      517 non-null float64
# DC       517 non-null float64
# ISI      517 non-null float64
# temp     517 non-null float64
# RH       517 non-null int64
# wind     517 non-null float64
# rain     517 non-null float64
# area     517 non-null float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
forestfire.describe(include = "all")
# Out:
#                  X           Y month  day        FFMC         DMC          DC  \
# count   517.000000  517.000000   517  517  517.000000  517.000000  517.000000
# unique         NaN         NaN    12    7         NaN         NaN         NaN
# top            NaN         NaN   aug  sun         NaN         NaN         NaN
# freq           NaN         NaN   184   95         NaN         NaN         NaN
# mean      4.669246    4.299807   NaN  NaN   90.644681  110.872340  547.940039
# std       2.313778    1.229900   NaN  NaN    5.520111   64.046482  248.066192
# min       1.000000    2.000000   NaN  NaN   18.700000    1.100000    7.900000
# 25%       3.000000    4.000000   NaN  NaN   90.200000   68.600000  437.700000
# 50%       4.000000    4.000000   NaN  NaN   91.600000  108.300000  664.200000
# 75%       7.000000    5.000000   NaN  NaN   92.900000  142.400000  713.900000
# max       9.000000    9.000000   NaN  NaN   96.200000  291.300000  860.600000
#
#                ISI        temp          RH        wind        rain  \
# count   517.000000  517.000000  517.000000  517.000000  517.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      9.021663   18.889168   44.288201    4.017602    0.021663
# std       4.559477    5.806625   16.317469    1.791653    0.295959
# min       0.000000    2.200000   15.000000    0.400000    0.000000
# 25%       6.500000   15.500000   33.000000    2.700000    0.000000
# 50%       8.400000   19.300000   42.000000    4.000000    0.000000
# 75%      10.800000   22.800000   53.000000    4.900000    0.000000
# max      56.100000   33.300000  100.000000    9.400000    6.400000
#
#                area
# count    517.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean      12.847292
# std       63.655818
# min        0.000000
# 25%        0.000000
# 50%        0.520000
# 75%        6.570000
# max     1090.840000

# %%
forestfire.isnull().sum()
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %% [markdown]
# <h3> Univariate analysis</h3>

# %%
#forestfire['X'].plot.hist(bins = 10)

sns.distplot(forestfire['X'])
plt.show()

# %%
Sample_transformed, lambd = stats.boxcox(forestfire['X'])
sns.distplot(Sample_transformed)

# %%
forestfire['Y'].plot.hist(bins = 10)

# %%
sns.distplot(forestfire['Y'])
plt.show()

# %%
(forestfire['month'].value_counts()/len(forestfire['month']*100)).plot.bar()

# %%
(forestfire['day'].value_counts()/len(forestfire['day']*100)).plot.bar()

# %%
forestfire['FFMC'].plot.hist(bins = 10)

# %%
forestfire['DMC'].plot.hist(bins = 10)

# %%
sns.distplot(forestfire['DMC'])
plt.show()

# %%
forestfire['DC'].plot.hist(bins = 10)

# %%
forestfire['ISI'].plot.hist(bins = 10)

# %%
forestfire['temp'].plot.hist(bins = 10)

# %%
forestfire['RH'].plot.hist(bins = 10)

# %%
forestfire['wind'].plot.hist(bins = 10)

# %%
forestfire['rain'].plot.hist(bins = 10)

# %% [markdown]
# Distribution of Output variable

# %%
forestfire['area'].plot.hist(bins = 10)

# %% [markdown]
# <h3> Bi variate - Anlaysis </h3>

# %%
x = forestfire['X']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ X and area')
plt.legend(loc=0)

plt.xlabel("X")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = forestfire['Y']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ Y and area')
plt.legend(loc=0)

plt.xlabel("Y")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = forestfire['FFMC']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ FFMC  and area')
plt.legend(loc=0)

plt.xlabel("FFMC")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = forestfire['DMC']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ FFMC  and area')
plt.legend(loc=0)

plt.xlabel("DMC")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = forestfire['wind']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ FFMC  and area')
plt.legend(loc=0)

plt.xlabel("wind")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = forestfire['temp']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ FFMC  and area')
plt.legend(loc=0)

plt.xlabel("temp")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = forestfire['rain']
y = forestfire['area']
plt.figure(figsize =  (30, 10))
plt.scatter(x,y, alpha= 1, edgecolors='none', s=50)
plt.title('Relation_btw_ FFMC  and area')
plt.legend(loc=0)

plt.xlabel("rain")
plt.ylabel("area")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Find Multi collinearity

# %%
forestfire['month'].unique()
# Out:
# array(['mar', 'oct', 'aug', 'sep', 'apr', 'jun', 'jul', 'feb', 'jan',
#        'dec', 'may', 'nov'], dtype=object)

# %%
cleanup_nums = {
                "month": {"mar":3, "oct":10, "aug":8, "sep":9, "apr":4, "jun":6, "jul":7, "feb":2, "jan":1,
       "dec":12, "may":5, "nov":11 }}

# %%
forestfire.replace(cleanup_nums,inplace=True)

# %%
forestfire.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      3  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      3  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      3  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
corr = forestfire.corr()
plt.figure(figsize=(15,20))
sns.heatmap(forestfire.corr())

# %%
corr.to_excel("../output/forestfires - correlation.xlsx")

# %%
X= forestfire.drop(['area'], axis = 1)
Y = forestfire[['area']]
names  = list(X.columns)

# %%
inp_df = pd.DataFrame(X, columns = names)

# %%
dummy1 = pd.get_dummies(inp_df['day'], drop_first=True)
inp_df =  pd.concat([dummy1, inp_df], axis =1 )

# %%
inp_df.head()
# Out:
#    mon  sat  sun  thu  tue  wed  X  Y  month  day  FFMC   DMC     DC  ISI  \
# 0    0    0    0    0    0    0  7  5      3  fri  86.2  26.2   94.3  5.1
# 1    0    0    0    0    1    0  7  4     10  tue  90.6  35.4  669.1  6.7
# 2    0    1    0    0    0    0  7  4     10  sat  90.6  43.7  686.9  6.7
# 3    0    0    0    0    0    0  8  6      3  fri  91.7  33.3   77.5  9.0
# 4    0    0    1    0    0    0  8  6      3  sun  89.3  51.3  102.2  9.6
#
#    temp  RH  wind  rain
# 0   8.2  51   6.7   0.0
# 1  18.0  33   0.9   0.0
# 2  14.6  33   1.3   0.0
# 3   8.3  97   4.0   0.2
# 4  11.4  99   1.8   0.0

# %%
inp_df = inp_df.drop(['day'],  axis = 1)

# %%
inp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 17 columns):
# mon      517 non-null uint8
# sat      517 non-null uint8
# sun      517 non-null uint8
# thu      517 non-null uint8
# tue      517 non-null uint8
# wed      517 non-null uint8
# X        517 non-null int64
# Y        517 non-null int64
# month    517 non-null int64
# FFMC     517 non-null float64
# DMC      517 non-null float64
# DC       517 non-null float64
# ISI      517 non-null float64
# temp     517 non-null float64
# RH       517 non-null int64
# wind     517 non-null float64
# rain     517 non-null float64
# dtypes: float64(7), int64(4), uint8(6)
# memory usage: 47.6 KB

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["features"] = inp_df.columns
vif["vif_Factor"] = [variance_inflation_factor(inp_df.values, i) for i in range(inp_df.shape[1])]
vif
# Out:
#    features  vif_Factor
# 0       mon    1.945635
# 1       sat    2.027135
# 2       sun    2.163609
# 3       thu    1.782801
# 4       tue    1.779609
# 5       wed    1.679249
# 6         X    7.305895
# 7         Y   19.029546
# 8     month   60.850014
# 9      FFMC   80.231838
# 10      DMC    9.817701
# 11       DC   47.763235
# 12      ISI    6.731146
# 13     temp   30.213745
# 14       RH   13.109886
# 15     wind    7.088203
# 16     rain    1.061338

# %%
from sklearn.model_selection import train_test_split
sv_train, sv_test, tv_train, tv_test = train_test_split(inp_df, y, test_size=0.25, random_state=12)

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
lreg.fit(sv_train,tv_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lreg.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-143dea686f79> in <module>
# ----> 1 lreg.show()
#
# AttributeError: 'LinearRegression' object has no attribute 'show'

# %%
import statsmodels.regression.linear_model as sm
from sklearn import datasets, linear_model,metrics
#import statsmodels.formula.api as sm
regressor_OLS = sm.OLS(endog = tv_train, exog = sv_train).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   area   R-squared (uncentered):                   0.071
# Model:                            OLS   Adj. R-squared (uncentered):              0.028
# Method:                 Least Squares   F-statistic:                              1.666
# Date:                Fri, 06 Nov 2020   Prob (F-statistic):                      0.0470
# Time:                        13:42:50   Log-Likelihood:                         -2198.4
# No. Observations:                 387   AIC:                                      4431.
# Df Residuals:                     370   BIC:                                      4498.
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mon            6.9050     13.270      0.520      0.603     -19.188      32.998
# sat           21.7954     12.870      1.694      0.091      -3.512      47.103
# sun            3.6491     12.490      0.292      0.770     -20.912      28.210
# thu           14.2519     14.663      0.972      0.332     -14.582      43.086
# tue            7.0272     13.907      0.505      0.614     -20.319      34.373
# wed            3.0708     14.929      0.206      0.837     -26.285      32.427
# X              2.7458      1.902      1.444      0.150      -0.993       6.485
# Y             -0.1088      3.485     -0.031      0.975      -6.962       6.745
# month          2.5956      3.862      0.672      0.502      -4.999      10.191
# FFMC          -0.4086      0.373     -1.094      0.274      -1.143       0.326
# DMC            0.1172      0.091      1.281      0.201      -0.063       0.297
# DC            -0.0260      0.045     -0.578      0.564      -0.114       0.062
# ISI           -0.4568      0.928     -0.492      0.623      -2.282       1.369
# temp           0.9707      1.093      0.888      0.375      -1.179       3.120
# RH            -0.2064      0.295     -0.699      0.485      -0.787       0.374
# wind           1.9070      2.267      0.841      0.401      -2.551       6.365
# rain         -17.8235     36.246     -0.492      0.623     -89.098      53.451
# ==============================================================================
# Omnibus:                      700.868   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           348804.161
# Skew:                          11.099   Prob(JB):                         0.00
# Kurtosis:                     148.391   Cond. No.                     6.07e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 6.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
